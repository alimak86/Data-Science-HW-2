# %%
import numpy as data

# %%
import pandas as pd

# %%
list = pd.read_html("https://uk.wikipedia.org/wiki/%D0%9D%D0%B0%D1%81%D0%B5%D0%BB%D0%B5%D0%BD%D0%BD%D1%8F_%D0%A3%D0%BA%D1%80%D0%B0%D1%97%D0%BD%D0%B8",match="Коефіцієнт народжуваності") ## html is from the link

# %%
table = list[0] ## get a DataFrame object

# %%
table.head()
# Out:
#              Регіон   1950   1960   1970  1990  2000  2012 2014 2019
# 0              Крим  230.0  206.0  160.0   130    73   126    —    —
# 1         Вінницька  224.0  192.0  142.0   124    84   112  109   76
# 2         Волинська  247.0  250.0  179.0   153   112   148  141  101
# 3  Дніпропетровська  204.0  204.0  151.0   123    71   112  111   71
# 4          Донецька  271.0  214.0  140.0   109    61    98   82    —

# %%
table.shape
# Out:
# (28, 9)

# %%
table = table.replace("—",data.nan)

# %%
table.dtypes # all columns types are numeric except column = 0
# Out:
# Регіон     object
# 1950      float64
# 1960      float64
# 1970      float64
# 1990        int64
# 2000        int64
# 2012        int64
# 2014       object
# 2019       object
# dtype: object

# %%
width=len(table.columns)

# %%
width
# Out:
# 9

# %%
table = table.apply(pd.to_numeric,errors = "ignore")

# %%
table
# Out:
#                Регіон   1950   1960   1970  1990  2000  2012   2014   2019
# 0                Крим  230.0  206.0  160.0   130    73   126    NaN    NaN
# 1           Вінницька  224.0  192.0  142.0   124    84   112  109.0   76.0
# 2           Волинська  247.0  250.0  179.0   153   112   148  141.0  101.0
# 3    Дніпропетровська  204.0  204.0  151.0   123    71   112  111.0   71.0
# 4            Донецька  271.0  214.0  140.0   109    61    98   82.0    NaN
# 5         Житомирська  261.0  223.0  159.0   129    89   122  120.0   79.0
# 6        Закарпатська  314.0  273.0  207.0   168   115   151  146.0  104.0
# 7          Запорізька  219.0  197.0  150.0   124    71   106  106.0   68.0
# 8   Івано-Франківська  243.0  248.0  182.0   155   103   124  122.0   88.0
# 9            Київська  204.0  189.0  156.0   123    73   122  121.0   80.0
# 10     Кіровоградська  216.0  171.0  145.0   126    79   110  108.0   68.0
# ...

# %%
table.isnull().sum() #calculate nan in each column
# Out:
# Регіон    0
# 1950      2
# 1960      1
# 1970      1
# 1990      0
# 2000      0
# 2012      0
# 2014      2
# 2019      4
# dtype: int64

# %%
table = table.drop(len(table.index)-1,axis=0) ## remove last row

# %%
table = table.drop(0,axis=0) ## remove first row - years

# %%
means = table.iloc[:,1:width].mean() ## calculate means

# %%
means
# Out:
# 1950    231.083333
# 1960    207.640000
# 1970    155.840000
# 1990    130.615385
# 2000     82.576923
# 2012    116.192308
# 2014    111.440000
# 2019     80.173913
# dtype: float64

# %%
table = table.fillna(means) ## insert means into NaN

# %%
table
# Out:
#                Регіон        1950    1960    1970  1990  2000  2012    2014  \
# 1           Вінницька  224.000000  192.00  142.00   124    84   112  109.00
# 2           Волинська  247.000000  250.00  179.00   153   112   148  141.00
# 3    Дніпропетровська  204.000000  204.00  151.00   123    71   112  111.00
# 4            Донецька  271.000000  214.00  140.00   109    61    98   82.00
# 5         Житомирська  261.000000  223.00  159.00   129    89   122  120.00
# 6        Закарпатська  314.000000  273.00  207.00   168   115   151  146.00
# 7          Запорізька  219.000000  197.00  150.00   124    71   106  106.00
# 8   Івано-Франківська  243.000000  248.00  182.00   155   103   124  122.00
# 9            Київська  204.000000  189.00  156.00   123    73   122  121.00
# 10     Кіровоградська  216.000000  171.00  145.00   126    79   110  108.00
# 11          Луганська  262.000000  235.00  144.00   116    62    96   51.00
# ...

# %%
############################

# %%
ukraine_2019 = means.iloc[len(means)-1]

# %%
ukraine_2019 ## average birht in 2019
# Out:
# 80.17391304347827

# %%
regions_high_birth_2019 = table[table.iloc[:,width-1] > ukraine_2019]

# %%
regions_high_birth_2019 ## display regions with birht > average in 2019
# Out:
#                Регіон        1950   1960   1970  1990  2000  2012   2014  \
# 2           Волинська  247.000000  250.0  179.0   153   112   148  141.0
# 6        Закарпатська  314.000000  273.0  207.0   168   115   151  146.0
# 8   Івано-Франківська  243.000000  248.0  182.0   155   103   124  122.0
# 12          Львівська  234.000000  240.0  171.0   140    91   119  119.0
# 14            Одеська  241.000000  192.0  148.0   126    80   127  123.0
# 16         Рівненська  269.000000  267.0  193.0   158   118   159  148.0
# 20         Херсонська  208.000000  214.0  166.0   143    85   117  115.0
# 23        Чернівецька  247.000000  218.0  170.0   148   101   128  129.0
# 25               Київ  231.083333  174.0  159.0   120    73   120  121.0
#
#      2019
# 2   101.0
# 6   104.0
# 8    88.0
# 12   87.0
# 14   88.0
# 16  107.0
# 20   81.0
# 23   92.0
# 25  110.0

# %%
maximums = table.max()

# %%
maximums
# Out:
# Регіон    Чернігівська
# 1950             314.0
# 1960             273.0
# 1970             207.0
# 1990               168
# 2000               118
# 2012               159
# 2014             148.0
# 2019             110.0
# dtype: object

# %%
max_ukraine_2019 = maximums.iloc[len(maximums)-1]

# %%
max_ukraine_2019
# Out:
# 110.0

# %%
regions_maximum_birth_2019 = table[table.iloc[:,width-1] == max_ukraine_2019].iloc[:,0]

# %%
regions_maximum_birth_2019 ## region with maximum birth
# Out:
# 25    Київ
# Name: Регіон, dtype: object

# %%
import matplotlib as plt

# %%
bar_plot_x = table.iloc[:,0].values.tolist() ## list of regions names

# %%
bar_plot_y = table.iloc[:,width-1].values.tolist() ## list of data from the 2014 last column

# %%
df = pd.DataFrame({"Regions":bar_plot_x, "Birth, humans":bar_plot_y})

# %%
index = bar_plot_x

# %%
df.plot.bar(x="Regions",y="Birth, humans")
# Out:
# <Axes: xlabel='Regions'>
